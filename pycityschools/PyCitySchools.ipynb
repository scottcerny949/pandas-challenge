# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset. 
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %% [raw]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
#Calculate the total number of schools
show_schools = school_data_complete["school_name"].unique()
num_schools = int(len(show_schools))
#Calculate the total number of students
num_students = int(len(school_data_complete["Student ID"]))
#Calculate the total budget
total_budget = int(school_data_complete["budget"].unique().sum())
#Calculate the average math score
avg_math = round(school_data_complete["math_score"].mean(), 6)
#Calculate the average reading score
avg_read = round(school_data_complete["reading_score"].mean(), 6)
#Calculate the percentage of students with a passing math score (70 or greater)
math_pass = len(school_data_complete.loc[school_data_complete["math_score"] >= 70, :])
math_total = len(school_data_complete["math_score"])
math_pass_pct = round((math_pass / math_total)*100, 6)
#Calculate the percentage of students with a passing reading score (70 or greater)
read_pass = len(school_data_complete.loc[school_data_complete["reading_score"] >= 70, :])
read_total = len(school_data_complete["reading_score"])
read_pass_pct = round((read_pass / read_total)*100, 6)
#Calculate the percentage of students who passed math and reading (% Overall Passing)
both_pass = school_data_complete[(school_data_complete["math_score"] >= 70) & (school_data_complete["reading_score"] >= 70)]
both_pass_pct = round((len(both_pass) / num_students)*100, 6)
#Create a dataframe to hold the above results
summary_df = pd.DataFrame({"Total Schools": [num_schools],
                           "Total Students": [num_students],
                           "Total Budget": [total_budget],
                           "Average Math Score": [avg_math],
                           "Average Reading Score": [avg_read],
                           "% Passing Math": [math_pass_pct],
                           "% Passing Reading": [read_pass_pct],
                           "% Overall Passing": [both_pass_pct]
                            })
#Optional: give the displayed data cleaner formatting
summary_df2 = pd.DataFrame({"Total Schools": [num_schools],
                           "Total Students": [num_students],
                           "Total Budget": [total_budget],
                           "Average Math Score": [avg_math],
                           "Average Reading Score": [avg_read],
                           "% Passing Math": str(math_pass_pct)+"%",
                           "% Passing Reading": str(read_pass_pct)+"%",
                           "% Overall Passing": str(both_pass_pct)+"%",
                            })
summary_df2.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_6050e7ff_9d76_11eb_a99c_b4ae2bde42f4" ><thead>    <tr>        <th class="col_heading level0 col0" >Total Schools</th>        <th class="col_heading level0 col1" >Total Students</th>        <th class="col_heading level0 col2" >Total Budget</th>        <th class="col_heading level0 col3" >Average Math Score</th>        <th class="col_heading level0 col4" >Average Reading Score</th>        <th class="col_heading level0 col5" >% Passing Math</th>        <th class="col_heading level0 col6" >% Passing Reading</th>        <th class="col_heading level0 col7" >% Overall Passing</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_6050e7ff_9d76_11eb_a99c_b4ae2bde42f4row0_col0" class="data row0 col0" >15</td>
#                         <td id="T_6050e7ff_9d76_11eb_a99c_b4ae2bde42f4row0_col1" class="data row0 col1" >39170</td>
# ...

# %% [raw]
# ## School Summary
#
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
# * Create a dataframe to hold the above results

# %%
#Set School Name as index, group by school
grouped_schools = school_data_complete.set_index('school_name').groupby(['school_name'])
#School Type
school_type = school_data.set_index('school_name')['type']
#Total Students
student_tot = school_data.set_index('school_name')['size']
#Total School Budget
school_budget = school_data.set_index('school_name')['budget']
#Per Student Budget
#budget / size for each school
student_budget = school_data.set_index('school_name')['budget'] / school_data.set_index('school_name')['size']
#Average Math Score
school_math = grouped_schools["math_score"].mean()
#Average Reading Score
school_read = grouped_schools["reading_score"].mean()
#% Passing Math
school_math_pass = school_data_complete[school_data_complete["math_score"] >= 70]
school_math_pass_2 = (school_math_pass.groupby("school_name")["math_score"].count()/student_tot)*100
#% Passing Reading
school_read_pass = school_data_complete[school_data_complete["reading_score"] >= 70]
school_read_pass_2 = (school_math_pass.groupby("school_name")["reading_score"].count()/student_tot)*100
#% Overall Passing (The percentage of students that passed math and reading.)
school_over_pass = school_data_complete[(school_data_complete["math_score"] >= 70) & (school_data_complete["reading_score"] >= 70)]
school_over_pass_2 = (school_over_pass.groupby("school_name")["math_score"].count()/student_tot)*100
#Create a dataframe to hold the above results
school_summary = pd.DataFrame({
                             "School Type": school_type,
                             "Total Students": student_tot,
                             "Total School Budget": school_budget, 
                             "Per Student Budget": student_budget, 
                             "Average Math Score": school_math, 
                             "Average Reading Score": school_read, 
                             "% Passing Math": school_math_pass_2, 
                             "% Passing Reading": school_read_pass_2, 
                             "% Overall Passing": school_over_pass_2
                              })
school_summary
# Out:
#                       School Type  Total Students  Total School Budget  \
# Bailey High School       District            4976              3124928
# Cabrera High School       Charter            1858              1081356
# Figueroa High School     District            2949              1884411
# Ford High School         District            2739              1763916
# Griffin High School       Charter            1468               917500
# Hernandez High School    District            4635              3022020
# Holden High School        Charter             427               248087
# Huang High School        District            2917              1910635
# Johnson High School      District            4761              3094650
# Pena High School          Charter             962               585858
# Rodriguez High School    District            3999              2547363
# Shelton High School       Charter            1761              1056600
# ...

# %% [raw]
# ## Top Performing Schools (By % Overall Passing)
# * Sort and display the top five performing schools by % overall passing.

# %%
#Sort and display the top five performing schools by % overall passing
sorted_over_pass = school_summary.sort_values("% Overall Passing", ascending = False)
sorted_over_pass.head()
# Out:
#                     School Type  Total Students  Total School Budget  \
# Cabrera High School     Charter            1858              1081356
# Thomas High School      Charter            1635              1043130
# Griffin High School     Charter            1468               917500
# Wilson High School      Charter            2283              1319574
# Pena High School        Charter             962               585858
#
#                      Per Student Budget  Average Math Score  \
# Cabrera High School               582.0           83.061895
# Thomas High School                638.0           83.418349
# Griffin High School               625.0           83.351499
# Wilson High School                578.0           83.274201
# Pena High School                  609.0           83.839917
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School              83.975780       94.133477          94.133477
# ...

# %% [raw]
# ## Bottom Performing Schools (By % Overall Passing)
# * Sort and display the five worst-performing schools by % overall passing.

# %%
#Sort and display the five worst-performing schools by % overall passing.
bottom_over_pass = school_summary.sort_values("% Overall Passing")
bottom_over_pass.head()
# Out:
#                       School Type  Total Students  Total School Budget  \
# Rodriguez High School    District            3999              2547363
# Figueroa High School     District            2949              1884411
# Huang High School        District            2917              1910635
# Hernandez High School    District            4635              3022020
# Johnson High School      District            4761              3094650
#
#                        Per Student Budget  Average Math Score  \
# Rodriguez High School               637.0           76.842711
# Figueroa High School                639.0           76.711767
# Huang High School                   655.0           76.629414
# Hernandez High School               652.0           77.289752
# Johnson High School                 650.0           77.072464
#
#                        Average Reading Score  % Passing Math  \
# Rodriguez High School              80.744686       66.366592
# ...

# %% [raw]
# ## Math Scores by Grade
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
ninth = school_data_complete.loc[school_data_complete['grade'] == "9th"]
math9 = ninth.groupby("school_name")["math_score"].mean()
tenth = school_data_complete.loc[school_data_complete['grade'] == "10th"]
math10 = tenth.groupby("school_name")["math_score"].mean()
eleventh = school_data_complete.loc[school_data_complete['grade'] == "11th"]
math11 = eleventh.groupby("school_name")["math_score"].mean()
twelfth = school_data_complete.loc[school_data_complete['grade'] == "12th"]
math12 = twelfth.groupby("school_name")["math_score"].mean()
math_by_grade = pd.DataFrame({
                             "9th": math9,
                             "10th": math10,
                             "11th": math11, 
                             "12th": math12, 
                             })
math_by_grade
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %% [raw]
# ## Reading Score by Grade
# * Perform the same operations as above for reading scores

# %%
#Reading Score by Grade
#Perform the same operations as above for reading scores
read9 = ninth.groupby("school_name")["reading_score"].mean()
read10 = tenth.groupby("school_name")["reading_score"].mean()
read11 = eleventh.groupby("school_name")["reading_score"].mean()
read12 = twelfth.groupby("school_name")["reading_score"].mean()
read_by_grade = pd.DataFrame({
                             "9th": read9,
                             "10th": read10,
                             "11th": read11, 
                             "12th": read12, 
                             })
read_by_grade
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %% [raw]
# ## Scores by School Spending
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
#creating bins for wanted spending ranges and gave them descriptive names
by_spending2 = school_summary
bins = [0, 585, 630, 645, 680]
group_names = ["<$585", "$585-630", "$630-645", "$645-680"]
#sliced the data into the bins
pd.cut(by_spending2["Per Student Budget"], bins, labels=group_names).head()
#put the data into the new column we are going to use
by_spending2["Spending Ranges (Per Student)"] = pd.cut(by_spending2["Per Student Budget"], bins, labels=group_names)
# grouped and called out which columns to display.  calculated the mean for each of the wanted columns.
by_spending_group = by_spending2.groupby("Spending Ranges (Per Student)")
by_spending_group[["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing"]].mean()
# Out:
#                                Average Math Score  Average Reading Score  \
# Spending Ranges (Per Student)
# <$585                                   83.455399              83.933814
# $585-630                                81.899826              83.155286
# $630-645                                78.518855              81.624473
# $645-680                                76.997210              81.027843
#
#                                % Passing Math  % Passing Reading  \
# Spending Ranges (Per Student)
# <$585                               93.460096          93.460096
# $585-630                            87.133538          87.133538
# $630-645                            73.484209          73.484209
# $645-680                            66.164813          66.164813
#
#                                % Overall Passing
# Spending Ranges (Per Student)
# <$585                                  90.369459
# $585-630                               81.418596
# ...

# %% [raw]
# ## Scores by School Size
# * Perform the same operations as above, based on school size.

# %%
#creating bins for school size ranges and gave them descriptive names
bins2 = [0, 1000, 2000, 5000]
group_names2 = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]
by_size = school_summary
#sliced the data into the bins
pd.cut(by_size["Total Students"], bins2, labels=group_names2).head()
#put the data into the new column we are going to use
by_size["School Size"] = pd.cut(by_spending2["Total Students"], bins2, labels=group_names2)
by_size.head()
# grouped and called out which columns to display. 
by_size_group = by_size.groupby("School Size")
by_size_group[["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing"]].mean()
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small (<1000)                83.821598              83.929843       93.550225
# Medium (1000-2000)           83.374684              83.864438       93.599695
# Large (2000-5000)            77.746417              81.344493       69.963361
#
#                     % Passing Reading  % Overall Passing
# School Size
# Small (<1000)               93.550225          89.883853
# Medium (1000-2000)          93.599695          90.621535
# Large (2000-5000)           69.963361          58.286003

# %% [raw]
# ## Scores by School Type
# * Perform the same operations as above, based on school type

# %%
by_type = school_summary.set_index('School Type').groupby(['School Type'])
# called out which columns to display. 
by_type[["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing"]].mean()
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.473852              83.896421       93.620830
# District              76.956733              80.966636       66.548453
#
#              % Passing Reading  % Overall Passing
# School Type
# Charter              93.620830          90.432244
# District             66.548453          53.672208
